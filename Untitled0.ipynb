# %% [markdown]
# <a href="https://colab.research.google.com/github/Anvesh8263/DIP/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %% [markdown]
# # New Section

# %%
from google.colab.patches import cv2_imshow

# %%
img1 = cv2.imread("/content/cfpy logo.jpeg")

# %%
img2 = cv2.imread("/content/azadi-ka-amrit-mahotsav-template-design-7623d890f77005dc3ae555514e8125f9_screen.jpg")

# %%
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=L size=200x100 at 0x7F9BD40E9D30>

# %%
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=462x693 at 0x7F9BD40F1CD0>

# %%
img1.shape
# Out:
# (100, 200)

# %%
img2.shape
# Out:
# (693, 462, 3)

# %%
img1=cv2.resize(img1,(200,100))

# %%
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=L size=200x100 at 0x7F9BD2810250>

# %%
img2=cv2.resize(img2,(200,100))

# %%
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=200x100 at 0x7F9BD40F21F0>

# %%
img1.shape
# Out:
# (100, 200)

# %%
img2.shape
# Out:
# (100, 200, 3)

# %%
img2=cv2.cvtColor(img2,cv2.COLOR_RGB2GRAY)

# %%
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=L size=200x100 at 0x7F9BD40D87C0>

# %%
a=cv2.add(img1,img2)

# %%
cv2_imshow(a)
# Out:
# <PIL.Image.Image image mode=L size=200x100 at 0x7F9BE34D13D0>

# %%
a=cv2.subtract(img1,img2)

# %%
cv2_imshow(a)
# Out:
# <PIL.Image.Image image mode=L size=200x100 at 0x7F9BD40F14F0>

# %%
a=cv2.multiply(img1,img2)

# %%
cv2_imshow(a)
# Out:
# <PIL.Image.Image image mode=L size=200x100 at 0x7F9BD40E9F10>

# %%
a=cv2.divide(img1,img2)

# %%
cv2_imshow(a)
# Out:
# <PIL.Image.Image image mode=L size=200x100 at 0x7F9BD40E9F70>
